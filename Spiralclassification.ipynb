# %%
import random
import torch
from torch import nn, optim
import math
from IPython import display
from matplotlib import pyplot as plt
import numpy as np

import time

# %%
def set_default(figsize=(10, 10), dpi=100):
    plt.style.use(['dark_background', 'bmh'])
    plt.rc('axes', facecolor='k')
    plt.rc('figure', facecolor='k')
    plt.rc('figure', figsize=figsize, dpi=dpi)


def plot_data(X, y, d=0, auto=False, zoom=1):
    X = X.cpu()
    y = y.cpu()
    # Use c = y to color each point
    plt.scatter(X.numpy()[:, 0], X.numpy()[:, 1], c=y, s=20, cmap=plt.cm.Spectral)
    plt.axis('square')
    plt.axis(np.array((-1.1, 1.1, -1.1, 1.1)) * zoom)
    if auto is True: plt.axis('equal')
    #plt.axis('off')

    _m, _c = 0, '.15'
    plt.axvline(0, ymin=_m, color=_c, lw=1, zorder=0)
    plt.axhline(0, xmin=_m, color=_c, lw=1, zorder=0)

def plot_model(X, y, model):
    model.cpu()
    mesh = np.arange(-1.1, 1.1, 0.01)
    xx, yy = np.meshgrid(mesh, mesh)
    with torch.no_grad():
        data = torch.from_numpy(np.vstack((xx.reshape(-1), yy.reshape(-1))).T).float()
        Z = model(data).detach()
    Z = np.argmax(Z, axis=1).reshape(xx.shape)
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.3)
    plot_data(X, y)
    
def plot_model2(X, y, model, r2 = 5, step = 10):
    """
    Plot the subdomain partition predicted by the neuaral network
    """
    model.cpu()
    mesh = np.arange(-r2 -0.5, r2 + 0.5, 0.01)
    xx, yy = np.meshgrid(mesh, mesh)
    with torch.no_grad():
        data = torch.from_numpy(np.vstack((xx.reshape(-1), yy.reshape(-1))).T).float()
        Z = model(data).detach()
    Z = np.argmax(Z, axis=1).reshape(xx.shape)
    # Plot the sample points of each subdomain
    # plt.scatter(X.numpy()[:-1:step, 0], X.numpy()[:-1:step, 1], c=y[:-1:step], s=20, cmap=plt.cm.Spectral)
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.3)
    plt.ylabel('$x_2$')
    plt.xlabel('$x_1$')
    plt.title('Predicted domain partiton')

# %%
set_default()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
seed = 12345
random.seed(seed)
torch.manual_seed(seed)

# Input parameters.
N = 500  # number of sample points in each subdomain D_i
D = 2  # dimensions
C = 3  # number of sub-classes
H1 = 20  # number of neuros of the first hidden layer
H2 = 10  # number of neuros of the second hidden layer
H3 = 10  # number of neuros of the third hidden layer
H4 = 10 # number of neuros of the fourth hidden layer
noice = 0.2 # noice rate

# Allocation of the memories 
#  X: a 2D array for the matrix of order NC x D
#  y: a 1D array for the vector of order NC
X = torch.zeros(N * C, D).to(device)
y = torch.zeros(N * C, dtype=torch.long).to(device)

# Generate a uniform partition of interval [0, 1] for parameter variable t
#  t_j = j/N for j=0, 1, 2, ..., N
t = torch.linspace(0, 1, N)

# Length of each subinterval 
tau = 2 * math.pi / C

# %%
for i in range(C):  # Here i = 0, 1, 2, ..., C-1
    j = 0
    # Generate N numbers in the subinterval [tau*i, tau*(i+1)] with tau = 2pi/C
    theta = torch.linspace(tau * i, tau * (i + 1), N) + torch.randn(N) * noice
    # Generate the N sample points in the $i$th subdomain D_i
    for ix in range(N * i, N * (i + 1)):
        X[ix] = t[j] * torch.FloatTensor((
            math.sin(theta[j]), math.cos(theta[j])
        ))
        y[ix] = i
        j += 1

print("Shapes:")
print("X:", tuple(X.size()))
print("y:", tuple(y.size()))
#print('y=', y)
#print('X=', X)
# Out:
# Shapes:
# X: (1500, 2)
# y: (1500,)

# %%
plot_data(X, y)

# %%
learning_rate = 1e-3
lambda_l2 = 1e-5

# %%
# nn package to create our linear model
# each Linear module has a weight and bias
linear_model = nn.Sequential(
    nn.Linear(D, H1),
    nn.Linear(H1, H2),
    nn.Linear(H2, H3),
    nn.Linear(H3, C)
)
linear_model.to(device) #Convert to CUDA

# nn package has different loss functions.
# We can use the Mean Squared Error Loss Function: 
#     Loss = torch.nn.MSELoss()
#  or use the cross entropy loss function:
#     Loss = torch.nn.CrossEntropyLoss()

#Loss = torch.nn.MSELoss()
Loss = torch.nn.CrossEntropyLoss()

# we use the optim package to apply
# stochastic gradient descent for our parameter updates
optimizer = torch.optim.SGD(linear_model.parameters(), lr=learning_rate, weight_decay=lambda_l2) # built-in L2

# Training
for t in range(1000):
    
    # Feed forward to get the logits
    y_pred = linear_model(X)
    
    # Compute the loss and accuracy
    loss = Loss(y_pred, y)
    score, predicted = torch.max(y_pred, 1)
    acc = (y == predicted).sum().float() / len(y)
    print("[EPOCH]: %i, [LOSS]: %.6f, [ACCURACY]: %.3f" % (t, loss.item(), acc))
    display.clear_output(wait=True)
    
    # zero the gradients before running
    # the backward pass.
    optimizer.zero_grad()
    
    # Backward pass to compute the gradient
    # of loss w.r.t our learnable params. 
    loss.backward()
    
    # Update params
    optimizer.step()
# Out:
# [EPOCH]: 999, [LOSS]: 1.058248, [ACCURACY]: 0.595

# %%
print(linear_model)
plot_model(X, y, linear_model)
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=20, bias=True)
#   (1): Linear(in_features=20, out_features=10, bias=True)
#   (2): Linear(in_features=10, out_features=10, bias=True)
#   (3): Linear(in_features=10, out_features=3, bias=True)
# )

# %%
# nn package to create our linear model
# each Linear module has a weight and bias
# Note: Increasing the number of hidden layers can make the predicted function become more nonlinear
#       so that the prediction accuracy can be further improved. 
model = nn.Sequential(
    nn.Linear(D, H1),
    nn.ReLU(),
    nn.Linear(H1, H2),
    nn.ReLU(),
    nn.Linear(H2, H3),
    nn.ReLU(),
    nn.Linear(H3, C)
)
model.to(device)

# nn package also has different loss functions.
# we use cross entropy loss for our classification task
Loss = torch.nn.CrossEntropyLoss()

# we use the optim package to apply
# ADAM for our parameter updates
learning_rate = 0.1
lambda_l2 = 1e-5
#optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate,  weight_decay=lambda_l2) 
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=lambda_l2) # built-in L2

# e = 1.  # plotting purpose

# Training
eps = 0.95
IteMax = 500
length4y = len(y)
acc = 0.0
ite = 0

# Start the timer by perf_counter(), which measures the time in seconds from this moment 
tic = time.perf_counter()

while acc < eps and ite < IteMax:
    
    # Get the predicted value y_pred of the target function value y at the input data X
    y_pred = model(X)
    
    # Compute the loss and accuracy
    loss = Loss(y_pred, y)
    score, predicted = torch.max(y_pred, 1)
    acc = (y == predicted).sum().float() / len(y)
    print("[EPOCH]: %i, [LOSS]: %.6f, [ACCURACY]: %.3f" % (ite, loss.item(), acc))
    #display.clear_output(wait=True)
    
    # zero the gradients before running
    # the backward pass.
    optimizer.zero_grad()
    
    # Calculate the gradient vector of the loss function with respect to parameters w
    #  by loss.backward()
    loss.backward()
    
    # Update the parameters w by the grandient descent method
    #  w = w + lr * gradient
    optimizer.step()
    # Increase the number of iteration by 1
    ite += 1

# Set another time counter
toc = time.perf_counter()
# Time cost between tic and toc is toc - tic
print(f"Training the nonlinear model takes {toc - tic:0.4f} seconds")
# Out:
# [EPOCH]: 0, [LOSS]: 1.103714, [ACCURACY]: 0.194
# [EPOCH]: 1, [LOSS]: 1.095382, [ACCURACY]: 0.333
# [EPOCH]: 2, [LOSS]: 1.051817, [ACCURACY]: 0.571
# [EPOCH]: 3, [LOSS]: 0.951365, [ACCURACY]: 0.573
# [EPOCH]: 4, [LOSS]: 0.806188, [ACCURACY]: 0.676
# [EPOCH]: 5, [LOSS]: 0.670680, [ACCURACY]: 0.780
# [EPOCH]: 6, [LOSS]: 0.548835, [ACCURACY]: 0.699
# [EPOCH]: 7, [LOSS]: 0.442982, [ACCURACY]: 0.786
# [EPOCH]: 8, [LOSS]: 0.328745, [ACCURACY]: 0.857
# [EPOCH]: 9, [LOSS]: 0.246006, [ACCURACY]: 0.886
# [EPOCH]: 10, [LOSS]: 0.195389, [ACCURACY]: 0.916
# [EPOCH]: 11, [LOSS]: 0.170168, [ACCURACY]: 0.933
# [EPOCH]: 12, [LOSS]: 0.219606, [ACCURACY]: 0.907
# [EPOCH]: 13, [LOSS]: 0.184927, [ACCURACY]: 0.919
# [EPOCH]: 14, [LOSS]: 0.233810, [ACCURACY]: 0.915
# [EPOCH]: 15, [LOSS]: 0.170187, [ACCURACY]: 0.907
# [EPOCH]: 16, [LOSS]: 0.184374, [ACCURACY]: 0.915
# [EPOCH]: 17, [LOSS]: 0.101167, [ACCURACY]: 0.964
# Training the nonlinear model takes 0.0794 seconds

# %%
print(model)
plot_model(X, y, model)
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=20, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=20, out_features=10, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=10, out_features=10, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=10, out_features=3, bias=True)
# )

# %% [markdown]
# # Network with 3 hidden layers

# %%
# nn package to create our linear model
# each Linear module has a weight and bias
# Note: Increasing the number of hidden layers can make the predicted function become more nonlinear
#       so that the prediction accuracy can be further improved. 
model3 = nn.Sequential(
    nn.Linear(D, H1),
    nn.ReLU(),
    nn.Linear(H1, H2),
    nn.ReLU(),
    nn.Linear(H2, H3),
    nn.ReLU(),
    nn.Linear(H3, H4),
    nn.ReLU(),
    nn.Linear(H4, C)
)
model3.to(device)

# nn package also has different loss functions.
# we use cross entropy loss for our classification task
Loss = torch.nn.CrossEntropyLoss()

# we use the optim package to apply
# ADAM for our parameter updates
learning_rate = 0.1
lambda_l2 = 1e-5
#optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate,  weight_decay=lambda_l2) 
optimizer = torch.optim.Adam(model3.parameters(), lr=learning_rate, weight_decay=lambda_l2) # built-in L2

# e = 1.  # plotting purpose

# Training
eps = 0.95
IteMax = 500
length4y = len(y)
acc = 0.0
ite = 0

# Start the timer by perf_counter(), which measures the time in seconds from this moment 
tic = time.perf_counter()

while acc < eps and ite < IteMax:
    
    # Get the predicted value y_pred of the target function value y at the input data X
    y_pred = model3(X)
    
    # Compute the loss and accuracy
    loss = Loss(y_pred, y)
    score, predicted = torch.max(y_pred, 1)
    acc = (y == predicted).sum().float() / len(y)
    print("[EPOCH]: %i, [LOSS]: %.6f, [ACCURACY]: %.3f" % (ite, loss.item(), acc))
    #display.clear_output(wait=True)
    
    # zero the gradients before running
    # the backward pass.
    optimizer.zero_grad()
    
    # Calculate the gradient vector of the loss function with respect to parameters w
    #  by loss.backward()
    loss.backward()
    
    # Update the parameters w by the grandient descent method
    #  w = w + lr * gradient
    optimizer.step()
    # Increase the number of iteration by 1
    ite += 1

# Set another time counter
toc = time.perf_counter()
# Time cost between tic and toc is toc - tic
print(f"Training the nonlinear model takes {toc - tic:0.4f} seconds")
# Out:
# [EPOCH]: 0, [LOSS]: 1.103272, [ACCURACY]: 0.333
# [EPOCH]: 1, [LOSS]: 1.104169, [ACCURACY]: 0.199
# [EPOCH]: 2, [LOSS]: 1.104939, [ACCURACY]: 0.333
# [EPOCH]: 3, [LOSS]: 1.038010, [ACCURACY]: 0.491
# [EPOCH]: 4, [LOSS]: 0.976964, [ACCURACY]: 0.483
# [EPOCH]: 5, [LOSS]: 0.821905, [ACCURACY]: 0.655
# [EPOCH]: 6, [LOSS]: 0.741196, [ACCURACY]: 0.593
# [EPOCH]: 7, [LOSS]: 0.660888, [ACCURACY]: 0.642
# [EPOCH]: 8, [LOSS]: 0.582293, [ACCURACY]: 0.644
# [EPOCH]: 9, [LOSS]: 0.571030, [ACCURACY]: 0.698
# [EPOCH]: 10, [LOSS]: 0.501176, [ACCURACY]: 0.705
# [EPOCH]: 11, [LOSS]: 0.481395, [ACCURACY]: 0.801
# [EPOCH]: 12, [LOSS]: 0.414884, [ACCURACY]: 0.811
# [EPOCH]: 13, [LOSS]: 0.431144, [ACCURACY]: 0.862
# [EPOCH]: 14, [LOSS]: 0.357886, [ACCURACY]: 0.886
# [EPOCH]: 15, [LOSS]: 0.339999, [ACCURACY]: 0.885
# [EPOCH]: 16, [LOSS]: 0.276359, [ACCURACY]: 0.895
# [EPOCH]: 17, [LOSS]: 0.256177, [ACCURACY]: 0.894
# [EPOCH]: 18, [LOSS]: 0.233318, [ACCURACY]: 0.903
# [EPOCH]: 19, [LOSS]: 0.187814, [ACCURACY]: 0.936
# [EPOCH]: 20, [LOSS]: 0.180308, [ACCURACY]: 0.945
# [EPOCH]: 21, [LOSS]: 0.132105, [ACCURACY]: 0.965
# Training the nonlinear model takes 0.1211 seconds

# %%
print(model3)
plot_model(X, y, model3)
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=20, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=20, out_features=10, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=10, out_features=10, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=10, out_features=10, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=10, out_features=3, bias=True)
# )

# %% [markdown]
# # Number of neurons

# %%
h1 = 50  # number of neuros of the first hidden layer
h2 = 25  # number of neuros of the second hidden layer
h3 = 25  # number of neuros of the third hidden layer
h4 = 10 # number of neuros of the fourth hidden layer

# %%
# nn package to create our linear model
# each Linear module has a weight and bias
# Note: Increasing the number of hidden layers can make the predicted function become more nonlinear
#       so that the prediction accuracy can be further improved. 
model4 = nn.Sequential(
    nn.Linear(D, h1),
    nn.ReLU(),
    nn.Linear(h1, h2),
    nn.ReLU(),
    nn.Linear(h2, h3),
    nn.ReLU(),
    nn.Linear(h3, h4),
    nn.ReLU(),
    nn.Linear(h4, C)
)
model4.to(device)

# nn package also has different loss functions.
# we use cross entropy loss for our classification task
Loss = torch.nn.CrossEntropyLoss()

# we use the optim package to apply
# ADAM for our parameter updates
learning_rate = 0.1
lambda_l2 = 1e-5
#optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate,  weight_decay=lambda_l2) 
optimizer = torch.optim.Adam(model4.parameters(), lr=learning_rate, weight_decay=lambda_l2) # built-in L2

# e = 1.  # plotting purpose

# Training
eps = 0.95
IteMax = 500
length4y = len(y)
acc = 0.0
ite = 0

# Start the timer by perf_counter(), which measures the time in seconds from this moment 
tic = time.perf_counter()

while acc < eps and ite < IteMax:
    
    # Get the predicted value y_pred of the target function value y at the input data X
    y_pred = model4(X)
    
    # Compute the loss and accuracy
    loss = Loss(y_pred, y)
    score, predicted = torch.max(y_pred, 1)
    acc = (y == predicted).sum().float() / len(y)
    print("[EPOCH]: %i, [LOSS]: %.6f, [ACCURACY]: %.3f" % (ite, loss.item(), acc))
    #display.clear_output(wait=True)
    
    # zero the gradients before running
    # the backward pass.
    optimizer.zero_grad()
    
    # Calculate the gradient vector of the loss function with respect to parameters w
    #  by loss.backward()
    loss.backward()
    
    # Update the parameters w by the grandient descent method
    #  w = w + lr * gradient
    optimizer.step()
    # Increase the number of iteration by 1
    ite += 1

# Set another time counter
toc = time.perf_counter()
# Time cost between tic and toc is toc - tic
print(f"Training the nonlinear model takes {toc - tic:0.4f} seconds")
# Out:
# [EPOCH]: 0, [LOSS]: 1.104381, [ACCURACY]: 0.333
# [EPOCH]: 1, [LOSS]: 1.402225, [ACCURACY]: 0.333
# [EPOCH]: 2, [LOSS]: 1.070715, [ACCURACY]: 0.333
# [EPOCH]: 3, [LOSS]: 1.029544, [ACCURACY]: 0.333
# [EPOCH]: 4, [LOSS]: 0.912837, [ACCURACY]: 0.547
# [EPOCH]: 5, [LOSS]: 0.816916, [ACCURACY]: 0.573
# [EPOCH]: 6, [LOSS]: 0.708218, [ACCURACY]: 0.639
# [EPOCH]: 7, [LOSS]: 0.642944, [ACCURACY]: 0.765
# [EPOCH]: 8, [LOSS]: 0.581680, [ACCURACY]: 0.707
# [EPOCH]: 9, [LOSS]: 0.543608, [ACCURACY]: 0.842
# [EPOCH]: 10, [LOSS]: 0.407375, [ACCURACY]: 0.874
# [EPOCH]: 11, [LOSS]: 0.524555, [ACCURACY]: 0.735
# [EPOCH]: 12, [LOSS]: 0.506805, [ACCURACY]: 0.660
# [EPOCH]: 13, [LOSS]: 0.532141, [ACCURACY]: 0.783
# [EPOCH]: 14, [LOSS]: 0.578641, [ACCURACY]: 0.737
# [EPOCH]: 15, [LOSS]: 0.490935, [ACCURACY]: 0.820
# [EPOCH]: 16, [LOSS]: 0.343759, [ACCURACY]: 0.809
# [EPOCH]: 17, [LOSS]: 0.185773, [ACCURACY]: 0.935
# [EPOCH]: 18, [LOSS]: 0.215082, [ACCURACY]: 0.901
# [EPOCH]: 19, [LOSS]: 0.243022, [ACCURACY]: 0.871
# [EPOCH]: 20, [LOSS]: 0.129275, [ACCURACY]: 0.941
# [EPOCH]: 21, [LOSS]: 0.099341, [ACCURACY]: 0.968
# Training the nonlinear model takes 0.1095 seconds

# %%
print(model3)
plot_model(X, y, model3)
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=20, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=20, out_features=10, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=10, out_features=10, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=10, out_features=10, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=10, out_features=3, bias=True)
# )

# %% [markdown]
# # Different activation function

# %%
# nn package to create our linear model
# each Linear module has a weight and bias
# Note: Increasing the number of hidden layers can make the predicted function become more nonlinear
#       so that the prediction accuracy can be further improved. 
model5 = nn.Sequential(
    nn.Linear(D, h1),
    nn.LeakyReLU(),
    nn.Linear(h1, h2),
    nn.LeakyReLU(),
    nn.Linear(h2, h3),
    nn.LeakyReLU(),
    nn.Linear(h3, h4),
    nn.LeakyReLU(),
    nn.Linear(h4, C)
)
model5.to(device)

# nn package also has different loss functions.
# we use cross entropy loss for our classification task
Loss = torch.nn.CrossEntropyLoss()

# we use the optim package to apply
# ADAM for our parameter updates
learning_rate = 0.1
lambda_l2 = 1e-5
#optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate,  weight_decay=lambda_l2) 
optimizer = torch.optim.Adam(model5.parameters(), lr=learning_rate, weight_decay=lambda_l2) # built-in L2

# e = 1.  # plotting purpose

# Training
eps = 0.95
IteMax = 500
length4y = len(y)
acc = 0.0
ite = 0

# Start the timer by perf_counter(), which measures the time in seconds from this moment 
tic = time.perf_counter()

while acc < eps and ite < IteMax:
    
    # Get the predicted value y_pred of the target function value y at the input data X
    y_pred = model5(X)
    
    # Compute the loss and accuracy
    loss = Loss(y_pred, y)
    score, predicted = torch.max(y_pred, 1)
    acc = (y == predicted).sum().float() / len(y)
    print("[EPOCH]: %i, [LOSS]: %.6f, [ACCURACY]: %.3f" % (ite, loss.item(), acc))
    #display.clear_output(wait=True)
    
    # zero the gradients before running
    # the backward pass.
    optimizer.zero_grad()
    
    # Calculate the gradient vector of the loss function with respect to parameters w
    #  by loss.backward()
    loss.backward()
    
    # Update the parameters w by the grandient descent method
    #  w = w + lr * gradient
    optimizer.step()
    # Increase the number of iteration by 1
    ite += 1

# Set another time counter
toc = time.perf_counter()
# Time cost between tic and toc is toc - tic
print(f"Training the nonlinear model takes {toc - tic:0.4f} seconds")
# Out:
# [EPOCH]: 0, [LOSS]: 1.101879, [ACCURACY]: 0.333
# [EPOCH]: 1, [LOSS]: 1.113106, [ACCURACY]: 0.333
# [EPOCH]: 2, [LOSS]: 1.124953, [ACCURACY]: 0.333
# [EPOCH]: 3, [LOSS]: 1.091302, [ACCURACY]: 0.613
# [EPOCH]: 4, [LOSS]: 0.993841, [ACCURACY]: 0.443
# [EPOCH]: 5, [LOSS]: 0.866905, [ACCURACY]: 0.541
# [EPOCH]: 6, [LOSS]: 0.673464, [ACCURACY]: 0.775
# [EPOCH]: 7, [LOSS]: 0.563450, [ACCURACY]: 0.779
# [EPOCH]: 8, [LOSS]: 0.373726, [ACCURACY]: 0.872
# [EPOCH]: 9, [LOSS]: 0.291381, [ACCURACY]: 0.891
# [EPOCH]: 10, [LOSS]: 0.228753, [ACCURACY]: 0.929
# [EPOCH]: 11, [LOSS]: 0.188260, [ACCURACY]: 0.933
# [EPOCH]: 12, [LOSS]: 0.134272, [ACCURACY]: 0.960
# Training the nonlinear model takes 0.0706 seconds

# %%
print(model5)
plot_model(X, y, model5)
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=50, bias=True)
#   (1): LeakyReLU(negative_slope=0.01)
#   (2): Linear(in_features=50, out_features=25, bias=True)
#   (3): LeakyReLU(negative_slope=0.01)
#   (4): Linear(in_features=25, out_features=25, bias=True)
#   (5): LeakyReLU(negative_slope=0.01)
#   (6): Linear(in_features=25, out_features=10, bias=True)
#   (7): LeakyReLU(negative_slope=0.01)
#   (8): Linear(in_features=10, out_features=3, bias=True)
# )

# %% [markdown]
# # SGD loss function

# %%
# nn package to create our linear model
# each Linear module has a weight and bias
# Note: Increasing the number of hidden layers can make the predicted function become more nonlinear
#       so that the prediction accuracy can be further improved. 
model6 = nn.Sequential(
    nn.Linear(D, h1),
    nn.LeakyReLU(),
    nn.Linear(h1, h2),
    nn.LeakyReLU(),
    nn.Linear(h2, h3),
    nn.LeakyReLU(),
    nn.Linear(h3, h4),
    nn.LeakyReLU(),
    nn.Linear(h4, C)
)
model6.to(device)

# nn package also has different loss functions.
# we use cross entropy loss for our classification task
Loss = torch.nn.CrossEntropyLoss()

# we use the optim package to apply
# ADAM for our parameter updates
learning_rate = 0.1
lambda_l2 = 1e-5
optimizer = torch.optim.SGD(model6.parameters(), lr=learning_rate,  weight_decay=lambda_l2) 
#optimizer = torch.optim.Adam(model6.parameters(), lr=learning_rate, weight_decay=lambda_l2) # built-in L2

# e = 1.  # plotting purpose

# Training
eps = 0.95
IteMax = 500
length4y = len(y)
acc = 0.0
ite = 0

# Start the timer by perf_counter(), which measures the time in seconds from this moment 
tic = time.perf_counter()

while acc < eps and ite < IteMax:
    
    # Get the predicted value y_pred of the target function value y at the input data X
    y_pred = model6(X)
    
    # Compute the loss and accuracy
    loss = Loss(y_pred, y)
    score, predicted = torch.max(y_pred, 1)
    acc = (y == predicted).sum().float() / len(y)
    print("[EPOCH]: %i, [LOSS]: %.6f, [ACCURACY]: %.3f" % (ite, loss.item(), acc))
    #display.clear_output(wait=True)
    
    # zero the gradients before running
    # the backward pass.
    optimizer.zero_grad()
    
    # Calculate the gradient vector of the loss function with respect to parameters w
    #  by loss.backward()
    loss.backward()
    
    # Update the parameters w by the grandient descent method
    #  w = w + lr * gradient
    optimizer.step()
    # Increase the number of iteration by 1
    ite += 1

# Set another time counter
toc = time.perf_counter()
# Time cost between tic and toc is toc - tic
print(f"Training the nonlinear model takes {toc - tic:0.4f} seconds")
# Out:
# [EPOCH]: 0, [LOSS]: 1.116402, [ACCURACY]: 0.333
# [EPOCH]: 1, [LOSS]: 1.115142, [ACCURACY]: 0.333
# [EPOCH]: 2, [LOSS]: 1.113932, [ACCURACY]: 0.333
# [EPOCH]: 3, [LOSS]: 1.112788, [ACCURACY]: 0.333
# [EPOCH]: 4, [LOSS]: 1.111699, [ACCURACY]: 0.333
# [EPOCH]: 5, [LOSS]: 1.110658, [ACCURACY]: 0.333
# [EPOCH]: 6, [LOSS]: 1.109723, [ACCURACY]: 0.333
# [EPOCH]: 7, [LOSS]: 1.108867, [ACCURACY]: 0.333
# [EPOCH]: 8, [LOSS]: 1.108073, [ACCURACY]: 0.333
# [EPOCH]: 9, [LOSS]: 1.107329, [ACCURACY]: 0.333
# [EPOCH]: 10, [LOSS]: 1.106632, [ACCURACY]: 0.333
# [EPOCH]: 11, [LOSS]: 1.105975, [ACCURACY]: 0.333
# [EPOCH]: 12, [LOSS]: 1.105358, [ACCURACY]: 0.333
# [EPOCH]: 13, [LOSS]: 1.104776, [ACCURACY]: 0.333
# [EPOCH]: 14, [LOSS]: 1.104229, [ACCURACY]: 0.333
# [EPOCH]: 15, [LOSS]: 1.103710, [ACCURACY]: 0.333
# [EPOCH]: 16, [LOSS]: 1.103223, [ACCURACY]: 0.333
# [EPOCH]: 17, [LOSS]: 1.102761, [ACCURACY]: 0.333
# [EPOCH]: 18, [LOSS]: 1.102324, [ACCURACY]: 0.333
# [EPOCH]: 19, [LOSS]: 1.101912, [ACCURACY]: 0.333
# [EPOCH]: 20, [LOSS]: 1.101523, [ACCURACY]: 0.333
# [EPOCH]: 21, [LOSS]: 1.101153, [ACCURACY]: 0.333
# [EPOCH]: 22, [LOSS]: 1.100802, [ACCURACY]: 0.333
# [EPOCH]: 23, [LOSS]: 1.100469, [ACCURACY]: 0.333
# [EPOCH]: 24, [LOSS]: 1.100153, [ACCURACY]: 0.333
# [EPOCH]: 25, [LOSS]: 1.099853, [ACCURACY]: 0.333
# [EPOCH]: 26, [LOSS]: 1.099567, [ACCURACY]: 0.333
# [EPOCH]: 27, [LOSS]: 1.099293, [ACCURACY]: 0.333
# [EPOCH]: 28, [LOSS]: 1.099034, [ACCURACY]: 0.333
# [EPOCH]: 29, [LOSS]: 1.098785, [ACCURACY]: 0.333
# [EPOCH]: 30, [LOSS]: 1.098547, [ACCURACY]: 0.333
# [EPOCH]: 31, [LOSS]: 1.098320, [ACCURACY]: 0.333
# [EPOCH]: 32, [LOSS]: 1.098102, [ACCURACY]: 0.333
# [EPOCH]: 33, [LOSS]: 1.097892, [ACCURACY]: 0.333
# [EPOCH]: 34, [LOSS]: 1.097689, [ACCURACY]: 0.333
# [EPOCH]: 35, [LOSS]: 1.097492, [ACCURACY]: 0.333
# [EPOCH]: 36, [LOSS]: 1.097305, [ACCURACY]: 0.333
# [EPOCH]: 37, [LOSS]: 1.097122, [ACCURACY]: 0.333
# [EPOCH]: 38, [LOSS]: 1.096947, [ACCURACY]: 0.333
# [EPOCH]: 39, [LOSS]: 1.096775, [ACCURACY]: 0.333
# [EPOCH]: 40, [LOSS]: 1.096608, [ACCURACY]: 0.333
# [EPOCH]: 41, [LOSS]: 1.096445, [ACCURACY]: 0.335
# [EPOCH]: 42, [LOSS]: 1.096287, [ACCURACY]: 0.338
# [EPOCH]: 43, [LOSS]: 1.096134, [ACCURACY]: 0.343
# [EPOCH]: 44, [LOSS]: 1.095982, [ACCURACY]: 0.353
# [EPOCH]: 45, [LOSS]: 1.095832, [ACCURACY]: 0.365
# [EPOCH]: 46, [LOSS]: 1.095687, [ACCURACY]: 0.373
# [EPOCH]: 47, [LOSS]: 1.095543, [ACCURACY]: 0.382
# [EPOCH]: 48, [LOSS]: 1.095402, [ACCURACY]: 0.387
# [EPOCH]: 49, [LOSS]: 1.095262, [ACCURACY]: 0.396
# [EPOCH]: 50, [LOSS]: 1.095124, [ACCURACY]: 0.403
# [EPOCH]: 51, [LOSS]: 1.094985, [ACCURACY]: 0.415
# [EPOCH]: 52, [LOSS]: 1.094849, [ACCURACY]: 0.421
# [EPOCH]: 53, [LOSS]: 1.094713, [ACCURACY]: 0.427
# [EPOCH]: 54, [LOSS]: 1.094577, [ACCURACY]: 0.433
# [EPOCH]: 55, [LOSS]: 1.094441, [ACCURACY]: 0.441
# [EPOCH]: 56, [LOSS]: 1.094306, [ACCURACY]: 0.445
# [EPOCH]: 57, [LOSS]: 1.094170, [ACCURACY]: 0.449
# [EPOCH]: 58, [LOSS]: 1.094034, [ACCURACY]: 0.456
# [EPOCH]: 59, [LOSS]: 1.093899, [ACCURACY]: 0.457
# [EPOCH]: 60, [LOSS]: 1.093760, [ACCURACY]: 0.461
# [EPOCH]: 61, [LOSS]: 1.093622, [ACCURACY]: 0.463
# [EPOCH]: 62, [LOSS]: 1.093483, [ACCURACY]: 0.467
# [EPOCH]: 63, [LOSS]: 1.093341, [ACCURACY]: 0.469
# [EPOCH]: 64, [LOSS]: 1.093200, [ACCURACY]: 0.473
# [EPOCH]: 65, [LOSS]: 1.093056, [ACCURACY]: 0.476
# [EPOCH]: 66, [LOSS]: 1.092910, [ACCURACY]: 0.477
# [EPOCH]: 67, [LOSS]: 1.092762, [ACCURACY]: 0.481
# [EPOCH]: 68, [LOSS]: 1.092614, [ACCURACY]: 0.482
# [EPOCH]: 69, [LOSS]: 1.092464, [ACCURACY]: 0.487
# [EPOCH]: 70, [LOSS]: 1.092310, [ACCURACY]: 0.488
# [EPOCH]: 71, [LOSS]: 1.092155, [ACCURACY]: 0.490
# [EPOCH]: 72, [LOSS]: 1.091995, [ACCURACY]: 0.491
# [EPOCH]: 73, [LOSS]: 1.091834, [ACCURACY]: 0.493
# [EPOCH]: 74, [LOSS]: 1.091670, [ACCURACY]: 0.495
# [EPOCH]: 75, [LOSS]: 1.091500, [ACCURACY]: 0.497
# [EPOCH]: 76, [LOSS]: 1.091329, [ACCURACY]: 0.501
# [EPOCH]: 77, [LOSS]: 1.091154, [ACCURACY]: 0.503
# [EPOCH]: 78, [LOSS]: 1.090975, [ACCURACY]: 0.505
# [EPOCH]: 79, [LOSS]: 1.090794, [ACCURACY]: 0.508
# [EPOCH]: 80, [LOSS]: 1.090611, [ACCURACY]: 0.510
# [EPOCH]: 81, [LOSS]: 1.090424, [ACCURACY]: 0.512
# [EPOCH]: 82, [LOSS]: 1.090234, [ACCURACY]: 0.514
# [EPOCH]: 83, [LOSS]: 1.090039, [ACCURACY]: 0.515
# [EPOCH]: 84, [LOSS]: 1.089844, [ACCURACY]: 0.518
# [EPOCH]: 85, [LOSS]: 1.089642, [ACCURACY]: 0.523
# [EPOCH]: 86, [LOSS]: 1.089438, [ACCURACY]: 0.526
# [EPOCH]: 87, [LOSS]: 1.089227, [ACCURACY]: 0.528
# [EPOCH]: 88, [LOSS]: 1.089014, [ACCURACY]: 0.531
# [EPOCH]: 89, [LOSS]: 1.088794, [ACCURACY]: 0.532
# [EPOCH]: 90, [LOSS]: 1.088571, [ACCURACY]: 0.537
# [EPOCH]: 91, [LOSS]: 1.088340, [ACCURACY]: 0.539
# [EPOCH]: 92, [LOSS]: 1.088107, [ACCURACY]: 0.540
# [EPOCH]: 93, [LOSS]: 1.087865, [ACCURACY]: 0.542
# [EPOCH]: 94, [LOSS]: 1.087620, [ACCURACY]: 0.544
# [EPOCH]: 95, [LOSS]: 1.087367, [ACCURACY]: 0.546
# [EPOCH]: 96, [LOSS]: 1.087108, [ACCURACY]: 0.549
# [EPOCH]: 97, [LOSS]: 1.086842, [ACCURACY]: 0.555
# [EPOCH]: 98, [LOSS]: 1.086568, [ACCURACY]: 0.569
# [EPOCH]: 99, [LOSS]: 1.086287, [ACCURACY]: 0.580
# [EPOCH]: 100, [LOSS]: 1.086000, [ACCURACY]: 0.588
# [EPOCH]: 101, [LOSS]: 1.085704, [ACCURACY]: 0.602
# [EPOCH]: 102, [LOSS]: 1.085401, [ACCURACY]: 0.615
# [EPOCH]: 103, [LOSS]: 1.085087, [ACCURACY]: 0.631
# [EPOCH]: 104, [LOSS]: 1.084767, [ACCURACY]: 0.643
# [EPOCH]: 105, [LOSS]: 1.084436, [ACCURACY]: 0.654
# [EPOCH]: 106, [LOSS]: 1.084096, [ACCURACY]: 0.663
# [EPOCH]: 107, [LOSS]: 1.083745, [ACCURACY]: 0.669
# [EPOCH]: 108, [LOSS]: 1.083384, [ACCURACY]: 0.675
# [EPOCH]: 109, [LOSS]: 1.083012, [ACCURACY]: 0.683
# [EPOCH]: 110, [LOSS]: 1.082630, [ACCURACY]: 0.691
# [EPOCH]: 111, [LOSS]: 1.082235, [ACCURACY]: 0.701
# [EPOCH]: 112, [LOSS]: 1.081827, [ACCURACY]: 0.713
# [EPOCH]: 113, [LOSS]: 1.081406, [ACCURACY]: 0.721
# [EPOCH]: 114, [LOSS]: 1.080975, [ACCURACY]: 0.726
# [EPOCH]: 115, [LOSS]: 1.080528, [ACCURACY]: 0.733
# [EPOCH]: 116, [LOSS]: 1.080066, [ACCURACY]: 0.737
# [EPOCH]: 117, [LOSS]: 1.079588, [ACCURACY]: 0.743
# [EPOCH]: 118, [LOSS]: 1.079095, [ACCURACY]: 0.747
# [EPOCH]: 119, [LOSS]: 1.078585, [ACCURACY]: 0.754
# [EPOCH]: 120, [LOSS]: 1.078058, [ACCURACY]: 0.758
# [EPOCH]: 121, [LOSS]: 1.077511, [ACCURACY]: 0.763
# [EPOCH]: 122, [LOSS]: 1.076947, [ACCURACY]: 0.766
# [EPOCH]: 123, [LOSS]: 1.076362, [ACCURACY]: 0.768
# [EPOCH]: 124, [LOSS]: 1.075758, [ACCURACY]: 0.771
# [EPOCH]: 125, [LOSS]: 1.075132, [ACCURACY]: 0.775
# [EPOCH]: 126, [LOSS]: 1.074482, [ACCURACY]: 0.777
# [EPOCH]: 127, [LOSS]: 1.073807, [ACCURACY]: 0.777
# [EPOCH]: 128, [LOSS]: 1.073108, [ACCURACY]: 0.777
# [EPOCH]: 129, [LOSS]: 1.072382, [ACCURACY]: 0.775
# [EPOCH]: 130, [LOSS]: 1.071627, [ACCURACY]: 0.773
# [EPOCH]: 131, [LOSS]: 1.070840, [ACCURACY]: 0.773
# [EPOCH]: 132, [LOSS]: 1.070025, [ACCURACY]: 0.769
# [EPOCH]: 133, [LOSS]: 1.069174, [ACCURACY]: 0.768
# [EPOCH]: 134, [LOSS]: 1.068285, [ACCURACY]: 0.765
# [EPOCH]: 135, [LOSS]: 1.067364, [ACCURACY]: 0.764
# [EPOCH]: 136, [LOSS]: 1.066412, [ACCURACY]: 0.764
# [EPOCH]: 137, [LOSS]: 1.065425, [ACCURACY]: 0.762
# [EPOCH]: 138, [LOSS]: 1.064403, [ACCURACY]: 0.760
# [EPOCH]: 139, [LOSS]: 1.063344, [ACCURACY]: 0.760
# [EPOCH]: 140, [LOSS]: 1.062255, [ACCURACY]: 0.761
# [EPOCH]: 141, [LOSS]: 1.061133, [ACCURACY]: 0.760
# [EPOCH]: 142, [LOSS]: 1.059976, [ACCURACY]: 0.757
# [EPOCH]: 143, [LOSS]: 1.058778, [ACCURACY]: 0.759
# [EPOCH]: 144, [LOSS]: 1.057538, [ACCURACY]: 0.761
# [EPOCH]: 145, [LOSS]: 1.056252, [ACCURACY]: 0.763
# [EPOCH]: 146, [LOSS]: 1.054920, [ACCURACY]: 0.769
# [EPOCH]: 147, [LOSS]: 1.053534, [ACCURACY]: 0.764
# [EPOCH]: 148, [LOSS]: 1.052099, [ACCURACY]: 0.763
# [EPOCH]: 149, [LOSS]: 1.050603, [ACCURACY]: 0.762
# [EPOCH]: 150, [LOSS]: 1.049050, [ACCURACY]: 0.764
# [EPOCH]: 151, [LOSS]: 1.047430, [ACCURACY]: 0.763
# [EPOCH]: 152, [LOSS]: 1.045745, [ACCURACY]: 0.760
# [EPOCH]: 153, [LOSS]: 1.043995, [ACCURACY]: 0.761
# [EPOCH]: 154, [LOSS]: 1.042175, [ACCURACY]: 0.759
# [EPOCH]: 155, [LOSS]: 1.040285, [ACCURACY]: 0.759
# [EPOCH]: 156, [LOSS]: 1.038323, [ACCURACY]: 0.759
# [EPOCH]: 157, [LOSS]: 1.036289, [ACCURACY]: 0.758
# [EPOCH]: 158, [LOSS]: 1.034181, [ACCURACY]: 0.756
# [EPOCH]: 159, [LOSS]: 1.031993, [ACCURACY]: 0.753
# [EPOCH]: 160, [LOSS]: 1.029721, [ACCURACY]: 0.752
# [EPOCH]: 161, [LOSS]: 1.027362, [ACCURACY]: 0.751
# [EPOCH]: 162, [LOSS]: 1.024912, [ACCURACY]: 0.750
# [EPOCH]: 163, [LOSS]: 1.022364, [ACCURACY]: 0.749
# [EPOCH]: 164, [LOSS]: 1.019717, [ACCURACY]: 0.749
# [EPOCH]: 165, [LOSS]: 1.016964, [ACCURACY]: 0.749
# [EPOCH]: 166, [LOSS]: 1.014100, [ACCURACY]: 0.747
# [EPOCH]: 167, [LOSS]: 1.011118, [ACCURACY]: 0.745
# [EPOCH]: 168, [LOSS]: 1.008012, [ACCURACY]: 0.743
# [EPOCH]: 169, [LOSS]: 1.004776, [ACCURACY]: 0.741
# [EPOCH]: 170, [LOSS]: 1.001401, [ACCURACY]: 0.742
# [EPOCH]: 171, [LOSS]: 0.997886, [ACCURACY]: 0.742
# [EPOCH]: 172, [LOSS]: 0.994236, [ACCURACY]: 0.740
# [EPOCH]: 173, [LOSS]: 0.990439, [ACCURACY]: 0.739
# [EPOCH]: 174, [LOSS]: 0.986490, [ACCURACY]: 0.736
# [EPOCH]: 175, [LOSS]: 0.982383, [ACCURACY]: 0.738
# [EPOCH]: 176, [LOSS]: 0.978110, [ACCURACY]: 0.737
# [EPOCH]: 177, [LOSS]: 0.973668, [ACCURACY]: 0.735
# [EPOCH]: 178, [LOSS]: 0.969067, [ACCURACY]: 0.735
# [EPOCH]: 179, [LOSS]: 0.964299, [ACCURACY]: 0.733
# [EPOCH]: 180, [LOSS]: 0.959362, [ACCURACY]: 0.733
# [EPOCH]: 181, [LOSS]: 0.954257, [ACCURACY]: 0.731
# [EPOCH]: 182, [LOSS]: 0.949009, [ACCURACY]: 0.731
# [EPOCH]: 183, [LOSS]: 0.943636, [ACCURACY]: 0.730
# [EPOCH]: 184, [LOSS]: 0.938129, [ACCURACY]: 0.729
# [EPOCH]: 185, [LOSS]: 0.932476, [ACCURACY]: 0.729
# [EPOCH]: 186, [LOSS]: 0.926681, [ACCURACY]: 0.729
# [EPOCH]: 187, [LOSS]: 0.920742, [ACCURACY]: 0.728
# [EPOCH]: 188, [LOSS]: 0.914654, [ACCURACY]: 0.728
# [EPOCH]: 189, [LOSS]: 0.908425, [ACCURACY]: 0.725
# [EPOCH]: 190, [LOSS]: 0.902057, [ACCURACY]: 0.723
# [EPOCH]: 191, [LOSS]: 0.895554, [ACCURACY]: 0.723
# [EPOCH]: 192, [LOSS]: 0.888929, [ACCURACY]: 0.721
# [EPOCH]: 193, [LOSS]: 0.882185, [ACCURACY]: 0.721
# [EPOCH]: 194, [LOSS]: 0.875328, [ACCURACY]: 0.719
# [EPOCH]: 195, [LOSS]: 0.868370, [ACCURACY]: 0.715
# [EPOCH]: 196, [LOSS]: 0.861327, [ACCURACY]: 0.714
# [EPOCH]: 197, [LOSS]: 0.854225, [ACCURACY]: 0.714
# [EPOCH]: 198, [LOSS]: 0.847067, [ACCURACY]: 0.713
# [EPOCH]: 199, [LOSS]: 0.839865, [ACCURACY]: 0.713
# [EPOCH]: 200, [LOSS]: 0.832634, [ACCURACY]: 0.710
# [EPOCH]: 201, [LOSS]: 0.825382, [ACCURACY]: 0.706
# [EPOCH]: 202, [LOSS]: 0.818128, [ACCURACY]: 0.706
# [EPOCH]: 203, [LOSS]: 0.810884, [ACCURACY]: 0.704
# [EPOCH]: 204, [LOSS]: 0.803663, [ACCURACY]: 0.704
# [EPOCH]: 205, [LOSS]: 0.796488, [ACCURACY]: 0.704
# [EPOCH]: 206, [LOSS]: 0.789377, [ACCURACY]: 0.702
# [EPOCH]: 207, [LOSS]: 0.782348, [ACCURACY]: 0.703
# [EPOCH]: 208, [LOSS]: 0.775410, [ACCURACY]: 0.701
# [EPOCH]: 209, [LOSS]: 0.768578, [ACCURACY]: 0.701
# [EPOCH]: 210, [LOSS]: 0.761864, [ACCURACY]: 0.701
# [EPOCH]: 211, [LOSS]: 0.755274, [ACCURACY]: 0.698
# [EPOCH]: 212, [LOSS]: 0.748811, [ACCURACY]: 0.699
# [EPOCH]: 213, [LOSS]: 0.742488, [ACCURACY]: 0.699
# [EPOCH]: 214, [LOSS]: 0.736308, [ACCURACY]: 0.700
# [EPOCH]: 215, [LOSS]: 0.730274, [ACCURACY]: 0.699
# [EPOCH]: 216, [LOSS]: 0.724394, [ACCURACY]: 0.701
# [EPOCH]: 217, [LOSS]: 0.718668, [ACCURACY]: 0.701
# [EPOCH]: 218, [LOSS]: 0.713097, [ACCURACY]: 0.699
# [EPOCH]: 219, [LOSS]: 0.707679, [ACCURACY]: 0.699
# [EPOCH]: 220, [LOSS]: 0.702408, [ACCURACY]: 0.699
# [EPOCH]: 221, [LOSS]: 0.697285, [ACCURACY]: 0.698
# [EPOCH]: 222, [LOSS]: 0.692305, [ACCURACY]: 0.698
# [EPOCH]: 223, [LOSS]: 0.687468, [ACCURACY]: 0.699
# [EPOCH]: 224, [LOSS]: 0.682765, [ACCURACY]: 0.697
# [EPOCH]: 225, [LOSS]: 0.678188, [ACCURACY]: 0.699
# [EPOCH]: 226, [LOSS]: 0.673731, [ACCURACY]: 0.699
# [EPOCH]: 227, [LOSS]: 0.669385, [ACCURACY]: 0.699
# [EPOCH]: 228, [LOSS]: 0.665152, [ACCURACY]: 0.699
# [EPOCH]: 229, [LOSS]: 0.661020, [ACCURACY]: 0.698
# [EPOCH]: 230, [LOSS]: 0.656981, [ACCURACY]: 0.697
# [EPOCH]: 231, [LOSS]: 0.653022, [ACCURACY]: 0.697
# [EPOCH]: 232, [LOSS]: 0.649142, [ACCURACY]: 0.697
# [EPOCH]: 233, [LOSS]: 0.645334, [ACCURACY]: 0.697
# [EPOCH]: 234, [LOSS]: 0.641585, [ACCURACY]: 0.698
# [EPOCH]: 235, [LOSS]: 0.637888, [ACCURACY]: 0.702
# [EPOCH]: 236, [LOSS]: 0.634235, [ACCURACY]: 0.705
# [EPOCH]: 237, [LOSS]: 0.630616, [ACCURACY]: 0.707
# [EPOCH]: 238, [LOSS]: 0.627020, [ACCURACY]: 0.708
# [EPOCH]: 239, [LOSS]: 0.623438, [ACCURACY]: 0.710
# [EPOCH]: 240, [LOSS]: 0.619870, [ACCURACY]: 0.711
# [EPOCH]: 241, [LOSS]: 0.616313, [ACCURACY]: 0.715
# [EPOCH]: 242, [LOSS]: 0.612754, [ACCURACY]: 0.717
# [EPOCH]: 243, [LOSS]: 0.609187, [ACCURACY]: 0.719
# [EPOCH]: 244, [LOSS]: 0.605601, [ACCURACY]: 0.721
# [EPOCH]: 245, [LOSS]: 0.601989, [ACCURACY]: 0.725
# [EPOCH]: 246, [LOSS]: 0.598338, [ACCURACY]: 0.728
# [EPOCH]: 247, [LOSS]: 0.594642, [ACCURACY]: 0.730
# [EPOCH]: 248, [LOSS]: 0.590890, [ACCURACY]: 0.735
# [EPOCH]: 249, [LOSS]: 0.587085, [ACCURACY]: 0.735
# [EPOCH]: 250, [LOSS]: 0.583216, [ACCURACY]: 0.735
# [EPOCH]: 251, [LOSS]: 0.579272, [ACCURACY]: 0.738
# [EPOCH]: 252, [LOSS]: 0.575249, [ACCURACY]: 0.742
# [EPOCH]: 253, [LOSS]: 0.571141, [ACCURACY]: 0.746
# [EPOCH]: 254, [LOSS]: 0.566941, [ACCURACY]: 0.748
# [EPOCH]: 255, [LOSS]: 0.562639, [ACCURACY]: 0.753
# [EPOCH]: 256, [LOSS]: 0.558221, [ACCURACY]: 0.756
# [EPOCH]: 257, [LOSS]: 0.553680, [ACCURACY]: 0.759
# [EPOCH]: 258, [LOSS]: 0.549016, [ACCURACY]: 0.761
# [EPOCH]: 259, [LOSS]: 0.544188, [ACCURACY]: 0.762
# [EPOCH]: 260, [LOSS]: 0.539200, [ACCURACY]: 0.765
# [EPOCH]: 261, [LOSS]: 0.534051, [ACCURACY]: 0.765
# [EPOCH]: 262, [LOSS]: 0.528687, [ACCURACY]: 0.767
# [EPOCH]: 263, [LOSS]: 0.523110, [ACCURACY]: 0.771
# [EPOCH]: 264, [LOSS]: 0.517349, [ACCURACY]: 0.774
# [EPOCH]: 265, [LOSS]: 0.511415, [ACCURACY]: 0.777
# [EPOCH]: 266, [LOSS]: 0.505253, [ACCURACY]: 0.779
# [EPOCH]: 267, [LOSS]: 0.498901, [ACCURACY]: 0.783
# [EPOCH]: 268, [LOSS]: 0.492363, [ACCURACY]: 0.786
# [EPOCH]: 269, [LOSS]: 0.485642, [ACCURACY]: 0.791
# [EPOCH]: 270, [LOSS]: 0.478744, [ACCURACY]: 0.798
# [EPOCH]: 271, [LOSS]: 0.471669, [ACCURACY]: 0.805
# [EPOCH]: 272, [LOSS]: 0.464464, [ACCURACY]: 0.809
# [EPOCH]: 273, [LOSS]: 0.457124, [ACCURACY]: 0.815
# [EPOCH]: 274, [LOSS]: 0.449665, [ACCURACY]: 0.821
# [EPOCH]: 275, [LOSS]: 0.442120, [ACCURACY]: 0.825
# [EPOCH]: 276, [LOSS]: 0.434438, [ACCURACY]: 0.827
# [EPOCH]: 277, [LOSS]: 0.426700, [ACCURACY]: 0.829
# [EPOCH]: 278, [LOSS]: 0.418880, [ACCURACY]: 0.833
# [EPOCH]: 279, [LOSS]: 0.410999, [ACCURACY]: 0.839
# [EPOCH]: 280, [LOSS]: 0.403149, [ACCURACY]: 0.844
# [EPOCH]: 281, [LOSS]: 0.395356, [ACCURACY]: 0.851
# [EPOCH]: 282, [LOSS]: 0.387674, [ACCURACY]: 0.855
# [EPOCH]: 283, [LOSS]: 0.380092, [ACCURACY]: 0.861
# [EPOCH]: 284, [LOSS]: 0.372614, [ACCURACY]: 0.867
# [EPOCH]: 285, [LOSS]: 0.365216, [ACCURACY]: 0.871
# [EPOCH]: 286, [LOSS]: 0.357965, [ACCURACY]: 0.872
# [EPOCH]: 287, [LOSS]: 0.350872, [ACCURACY]: 0.875
# [EPOCH]: 288, [LOSS]: 0.343922, [ACCURACY]: 0.879
# [EPOCH]: 289, [LOSS]: 0.337099, [ACCURACY]: 0.881
# [EPOCH]: 290, [LOSS]: 0.330435, [ACCURACY]: 0.884
# [EPOCH]: 291, [LOSS]: 0.323950, [ACCURACY]: 0.885
# [EPOCH]: 292, [LOSS]: 0.317639, [ACCURACY]: 0.887
# [EPOCH]: 293, [LOSS]: 0.311485, [ACCURACY]: 0.889
# [EPOCH]: 294, [LOSS]: 0.305514, [ACCURACY]: 0.893
# [EPOCH]: 295, [LOSS]: 0.299739, [ACCURACY]: 0.893
# [EPOCH]: 296, [LOSS]: 0.294143, [ACCURACY]: 0.896
# [EPOCH]: 297, [LOSS]: 0.288712, [ACCURACY]: 0.895
# [EPOCH]: 298, [LOSS]: 0.283465, [ACCURACY]: 0.899
# [EPOCH]: 299, [LOSS]: 0.278396, [ACCURACY]: 0.899
# [EPOCH]: 300, [LOSS]: 0.273520, [ACCURACY]: 0.909
# [EPOCH]: 301, [LOSS]: 0.268816, [ACCURACY]: 0.903
# [EPOCH]: 302, [LOSS]: 0.264300, [ACCURACY]: 0.913
# [EPOCH]: 303, [LOSS]: 0.260030, [ACCURACY]: 0.907
# [EPOCH]: 304, [LOSS]: 0.256068, [ACCURACY]: 0.918
# [EPOCH]: 305, [LOSS]: 0.252536, [ACCURACY]: 0.911
# [EPOCH]: 306, [LOSS]: 0.249590, [ACCURACY]: 0.922
# [EPOCH]: 307, [LOSS]: 0.247801, [ACCURACY]: 0.914
# [EPOCH]: 308, [LOSS]: 0.247756, [ACCURACY]: 0.929
# [EPOCH]: 309, [LOSS]: 0.251441, [ACCURACY]: 0.905
# [EPOCH]: 310, [LOSS]: 0.260780, [ACCURACY]: 0.937
# [EPOCH]: 311, [LOSS]: 0.282283, [ACCURACY]: 0.857
# [EPOCH]: 312, [LOSS]: 0.314702, [ACCURACY]: 0.899
# [EPOCH]: 313, [LOSS]: 0.371182, [ACCURACY]: 0.812
# [EPOCH]: 314, [LOSS]: 0.420667, [ACCURACY]: 0.853
# [EPOCH]: 315, [LOSS]: 0.461345, [ACCURACY]: 0.791
# [EPOCH]: 316, [LOSS]: 0.452066, [ACCURACY]: 0.851
# [EPOCH]: 317, [LOSS]: 0.411135, [ACCURACY]: 0.807
# [EPOCH]: 318, [LOSS]: 0.347081, [ACCURACY]: 0.887
# [EPOCH]: 319, [LOSS]: 0.316644, [ACCURACY]: 0.838
# [EPOCH]: 320, [LOSS]: 0.281836, [ACCURACY]: 0.913
# [EPOCH]: 321, [LOSS]: 0.270077, [ACCURACY]: 0.860
# [EPOCH]: 322, [LOSS]: 0.252807, [ACCURACY]: 0.924
# [EPOCH]: 323, [LOSS]: 0.247907, [ACCURACY]: 0.877
# [EPOCH]: 324, [LOSS]: 0.237055, [ACCURACY]: 0.934
# [EPOCH]: 325, [LOSS]: 0.234264, [ACCURACY]: 0.889
# [EPOCH]: 326, [LOSS]: 0.226532, [ACCURACY]: 0.938
# [EPOCH]: 327, [LOSS]: 0.224997, [ACCURACY]: 0.897
# [EPOCH]: 328, [LOSS]: 0.219081, [ACCURACY]: 0.939
# [EPOCH]: 329, [LOSS]: 0.218409, [ACCURACY]: 0.901
# [EPOCH]: 330, [LOSS]: 0.213872, [ACCURACY]: 0.941
# [EPOCH]: 331, [LOSS]: 0.213743, [ACCURACY]: 0.903
# [EPOCH]: 332, [LOSS]: 0.209880, [ACCURACY]: 0.942
# [EPOCH]: 333, [LOSS]: 0.210455, [ACCURACY]: 0.903
# [EPOCH]: 334, [LOSS]: 0.207023, [ACCURACY]: 0.943
# [EPOCH]: 335, [LOSS]: 0.208153, [ACCURACY]: 0.903
# [EPOCH]: 336, [LOSS]: 0.204999, [ACCURACY]: 0.941
# [EPOCH]: 337, [LOSS]: 0.206959, [ACCURACY]: 0.901
# [EPOCH]: 338, [LOSS]: 0.204113, [ACCURACY]: 0.940
# [EPOCH]: 339, [LOSS]: 0.206815, [ACCURACY]: 0.901
# [EPOCH]: 340, [LOSS]: 0.204024, [ACCURACY]: 0.938
# [EPOCH]: 341, [LOSS]: 0.207437, [ACCURACY]: 0.898
# [EPOCH]: 342, [LOSS]: 0.204212, [ACCURACY]: 0.937
# [EPOCH]: 343, [LOSS]: 0.208143, [ACCURACY]: 0.896
# [EPOCH]: 344, [LOSS]: 0.204109, [ACCURACY]: 0.936
# [EPOCH]: 345, [LOSS]: 0.208218, [ACCURACY]: 0.893
# [EPOCH]: 346, [LOSS]: 0.203241, [ACCURACY]: 0.936
# [EPOCH]: 347, [LOSS]: 0.207122, [ACCURACY]: 0.894
# [EPOCH]: 348, [LOSS]: 0.201500, [ACCURACY]: 0.935
# [EPOCH]: 349, [LOSS]: 0.205344, [ACCURACY]: 0.894
# [EPOCH]: 350, [LOSS]: 0.199180, [ACCURACY]: 0.935
# [EPOCH]: 351, [LOSS]: 0.202811, [ACCURACY]: 0.896
# [EPOCH]: 352, [LOSS]: 0.196340, [ACCURACY]: 0.936
# [EPOCH]: 353, [LOSS]: 0.199806, [ACCURACY]: 0.898
# [EPOCH]: 354, [LOSS]: 0.193231, [ACCURACY]: 0.937
# [EPOCH]: 355, [LOSS]: 0.196564, [ACCURACY]: 0.900
# [EPOCH]: 356, [LOSS]: 0.189851, [ACCURACY]: 0.937
# [EPOCH]: 357, [LOSS]: 0.192996, [ACCURACY]: 0.901
# [EPOCH]: 358, [LOSS]: 0.186313, [ACCURACY]: 0.937
# [EPOCH]: 359, [LOSS]: 0.189173, [ACCURACY]: 0.903
# [EPOCH]: 360, [LOSS]: 0.182717, [ACCURACY]: 0.940
# [EPOCH]: 361, [LOSS]: 0.185559, [ACCURACY]: 0.904
# [EPOCH]: 362, [LOSS]: 0.179541, [ACCURACY]: 0.941
# [EPOCH]: 363, [LOSS]: 0.182405, [ACCURACY]: 0.906
# [EPOCH]: 364, [LOSS]: 0.176623, [ACCURACY]: 0.941
# [EPOCH]: 365, [LOSS]: 0.179329, [ACCURACY]: 0.908
# [EPOCH]: 366, [LOSS]: 0.174018, [ACCURACY]: 0.941
# [EPOCH]: 367, [LOSS]: 0.176762, [ACCURACY]: 0.909
# [EPOCH]: 368, [LOSS]: 0.171624, [ACCURACY]: 0.941
# [EPOCH]: 369, [LOSS]: 0.174262, [ACCURACY]: 0.911
# [EPOCH]: 370, [LOSS]: 0.169304, [ACCURACY]: 0.941
# [EPOCH]: 371, [LOSS]: 0.172072, [ACCURACY]: 0.915
# [EPOCH]: 372, [LOSS]: 0.167232, [ACCURACY]: 0.942
# [EPOCH]: 373, [LOSS]: 0.170005, [ACCURACY]: 0.915
# [EPOCH]: 374, [LOSS]: 0.165076, [ACCURACY]: 0.944
# [EPOCH]: 375, [LOSS]: 0.167908, [ACCURACY]: 0.915
# [EPOCH]: 376, [LOSS]: 0.163092, [ACCURACY]: 0.945
# [EPOCH]: 377, [LOSS]: 0.165713, [ACCURACY]: 0.916
# [EPOCH]: 378, [LOSS]: 0.161044, [ACCURACY]: 0.945
# [EPOCH]: 379, [LOSS]: 0.163676, [ACCURACY]: 0.917
# [EPOCH]: 380, [LOSS]: 0.159204, [ACCURACY]: 0.945
# [EPOCH]: 381, [LOSS]: 0.161913, [ACCURACY]: 0.918
# [EPOCH]: 382, [LOSS]: 0.157475, [ACCURACY]: 0.945
# [EPOCH]: 383, [LOSS]: 0.160276, [ACCURACY]: 0.919
# [EPOCH]: 384, [LOSS]: 0.155916, [ACCURACY]: 0.946
# [EPOCH]: 385, [LOSS]: 0.158707, [ACCURACY]: 0.919
# [EPOCH]: 386, [LOSS]: 0.154445, [ACCURACY]: 0.946
# [EPOCH]: 387, [LOSS]: 0.157291, [ACCURACY]: 0.920
# [EPOCH]: 388, [LOSS]: 0.153056, [ACCURACY]: 0.946
# [EPOCH]: 389, [LOSS]: 0.155896, [ACCURACY]: 0.921
# [EPOCH]: 390, [LOSS]: 0.151597, [ACCURACY]: 0.946
# [EPOCH]: 391, [LOSS]: 0.154302, [ACCURACY]: 0.921
# [EPOCH]: 392, [LOSS]: 0.149917, [ACCURACY]: 0.948
# [EPOCH]: 393, [LOSS]: 0.152629, [ACCURACY]: 0.925
# [EPOCH]: 394, [LOSS]: 0.148229, [ACCURACY]: 0.948
# [EPOCH]: 395, [LOSS]: 0.150993, [ACCURACY]: 0.925
# [EPOCH]: 396, [LOSS]: 0.146567, [ACCURACY]: 0.948
# [EPOCH]: 397, [LOSS]: 0.149179, [ACCURACY]: 0.927
# [EPOCH]: 398, [LOSS]: 0.144679, [ACCURACY]: 0.949
# [EPOCH]: 399, [LOSS]: 0.147122, [ACCURACY]: 0.931
# [EPOCH]: 400, [LOSS]: 0.142647, [ACCURACY]: 0.950
# Training the nonlinear model takes 1.7879 seconds

# %%
print(model6)
plot_model(X, y, model6)
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=50, bias=True)
#   (1): LeakyReLU(negative_slope=0.01)
#   (2): Linear(in_features=50, out_features=25, bias=True)
#   (3): LeakyReLU(negative_slope=0.01)
#   (4): Linear(in_features=25, out_features=25, bias=True)
#   (5): LeakyReLU(negative_slope=0.01)
#   (6): Linear(in_features=25, out_features=10, bias=True)
#   (7): LeakyReLU(negative_slope=0.01)
#   (8): Linear(in_features=10, out_features=3, bias=True)
# )
